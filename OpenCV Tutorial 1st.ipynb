# %%
import sys
sys.version
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageOps
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CC57-3985
#
#  Directory of C:\Users\DHANSHREE\PythonML
#
# 30-05-2020  13:05    <DIR>          .
# 30-05-2020  13:05    <DIR>          ..
# 30-05-2020  13:03    <DIR>          .ipynb_checkpoints
# 22-02-2020  14:22           296,566 1. Python Basics.ipynb
# 01-03-2020  18:55           152,896 2. Python Data Preprocessing for Machine Learning.ipynb
# 08-03-2020  10:02           409,215 3. Python Linear Regression.ipynb
# 12-05-2020  09:35           175,623 4. Python Classification.ipynb
# 23-03-2020  13:35            24,863 5. Python PCA.ipynb
# 04-04-2020  21:09            41,516 6. Python Clustering.ipynb
# 12-04-2020  15:59           111,345 6. Python Text Mining.ipynb
# 12-04-2020  16:01           238,288 7. Python Twitter Data Analysis.ipynb
# 08-03-2020  09:39           231,098 BostonHousingScatterPlot.png
# 08-03-2020  10:16            98,183 ConcreteStrengthScatterPlot.png
# ...

# %%
img=plt.imread('F:/PythonML/Python Datasets/Classification Datasets/coronavirus_1.jpg')
plt.imshow(img)

# %%
img.shape
# Out:
# (900, 1200, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageOps
# %matplotlib inline

# %%
img_pil=Image.fromarray(np.uint8(img))
img_pil=ImageOps.equalize(img_pil)
plt.imshow(img_pil)

# %%
img2=np.asarray(img_pil)
plt.imshow(img2)

# %%
plt.hist(img.ravel())
# Out:
# (array([ 170378., 1276322.,  845839.,  219248.,  244970.,  192078.,
#          132822.,   77380.,   49641.,   31322.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(img2.ravel())
# Out:
# (array([339690., 397903., 258172., 366822., 268889., 353031., 294380.,
#         311091., 327343., 322679.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
np.save('Origin_of_CoronaVirus',img2)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CC57-3985
#
#  Directory of C:\Users\DHANSHREE\PythonML
#
# 28-05-2020  14:59    <DIR>          .
# 28-05-2020  14:59    <DIR>          ..
# 28-05-2020  14:30    <DIR>          .ipynb_checkpoints
# 22-02-2020  14:22           296,566 1. Python Basics.ipynb
# 01-03-2020  18:55           152,896 2. Python Data Preprocessing for Machine Learning.ipynb
# 08-03-2020  10:02           409,215 3. Python Linear Regression.ipynb
# 12-05-2020  09:35           175,623 4. Python Classification.ipynb
# 23-03-2020  13:35            24,863 5. Python PCA.ipynb
# 04-04-2020  21:09            41,516 6. Python Clustering.ipynb
# 12-04-2020  15:59           111,345 6. Python Text Mining.ipynb
# 12-04-2020  16:01           238,288 7. Python Twitter Data Analysis.ipynb
# 08-03-2020  09:39           231,098 BostonHousingScatterPlot.png
# 08-03-2020  10:16            98,183 ConcreteStrengthScatterPlot.png
# ...

# %%
img3=np.load('Origin_of_CoronaVirus.npy')
