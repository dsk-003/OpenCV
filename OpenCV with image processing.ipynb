# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
img=cv2.imread('F:/PythonML/Python Datasets/Classification Datasets/lena.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#width height 
img.shape
# Out:
# (220, 220, 3)

# %%
plt.imshow(img)

# %%
#matplot RGB 
# OPENCV TO BGR

# %%
fin_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fin_img)

# %%
gra_image=cv2.imread('F:/PythonML/Python Datasets/Classification Datasets/lena.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gra_image)

# %%
plt.imshow(gra_image,cmap='gray')

# %%
plt.imshow(gra_image,cmap='magma')

# %%
plt.imshow(fin_img)

# %%
fin_img.shape
# Out:
# (220, 220, 3)

# %%
new_img=cv2.resize(fin_img,(500,900))

# %%
plt.imshow(new_img)

# %%
w_ratio=.5
h_ratio=.5

# %%
new_img=cv2.resize(fin_img,(0,0),fin_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (110, 110, 3)

# %%
new_img=cv2.flip(fin_img,0)
plt.imshow(new_img)

# %%
 new_img=cv2.flip(fin_img,1)
plt.imshow(new_img)

# %%
new_img=cv2.flip(fin_img,-1)
plt.imshow(new_img)

# %%
cv2.imwrite('new lena.png',fin_img)
# Out:
# True

# %%
cv2.imwrite('new1_lena.jpg',fin_img)
# Out:
# True

# %%
import cv2
img = cv2.imread('F:/PythonML/Python Datasets/Classification Datasets/dolphin.png')

cv2.imshow("original image",img)

edge_img = cv2.Canny(img,100,200)

cv2.imshow("Detected Edges", edge_img)

cv2.waitKey(0)
# Out:
# -1

# %%
import cv2
img = cv2.imread('F:/PythonML/Python Datasets/Classification Datasets/dolphin.png')
cv2.imshow("Original Image", img)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Scale Image", gray_img)
cv2.waitKey(0)
# Out:
# -1
